# %% [markdown]
# # Customer Shopping Behavior Analysis
#
# This notebook analyzes customer shopping patterns and behaviors using a retail dataset. We'll perform data cleaning, feature engineering, and prepare the data for further analysis.
#
# ## 1. Data Loading and Initial Setup
# We'll start by importing necessary libraries and loading our dataset. The data contains customer purchase information including demographics, purchase history, and shopping preferences.

# %%
import pandas as pd
import numpy as np

# If the file is a CSV (fixes the unicode escape by using a raw string)
df = pd.read_csv(r"data\customer_shopping_behavior.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %% [markdown]
# ## 2. Data Exploration and Quality Check
#
# Understanding our dataset's structure and content:
# - `df.info()`: Shows data types and null values
# - `df.describe()`: Provides statistical summary
# - `df.describe(include='int')`: Focuses on integer columns
# This helps identify potential data quality issues and guides our cleaning strategy.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.describe(include='int')
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Previous Purchases
# count  3900.000000  3900.000000            3900.000000         3900.000000
# mean   1950.500000    44.068462              59.764359           25.351538
# std    1125.977353    15.207589              23.685392           14.447125
# min       1.000000    18.000000              20.000000            1.000000
# 25%     975.750000    31.000000              39.000000           13.000000
# 50%    1950.500000    44.000000              60.000000           25.000000
# 75%    2925.250000    57.000000              81.000000           38.000000
# max    3900.000000    70.000000             100.000000           50.000000

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# unique                    NaN       50     4     25       4            NaN
# top                       NaN  Montana     M  Olive  Spring            NaN
# freq                      NaN       96  1755    177     999            NaN
# mean                59.764359      NaN   NaN    NaN     NaN       3.750065
# std                 23.685392      NaN   NaN    NaN     NaN       0.716983
# min                 20.000000      NaN   NaN    NaN     NaN       2.500000
# 25%                 39.000000      NaN   NaN    NaN     NaN       3.100000
# 50%                 60.000000      NaN   NaN    NaN     NaN       3.800000
# 75%                 81.000000      NaN   NaN    NaN     NaN       4.400000
# max                100.000000      NaN   NaN    NaN     NaN       5.000000
#
#        Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# count                 3900           3900             3900            3900
# unique                   2              6                2               2
# top                     No  Free Shipping               No              No
# freq                  2847            675             2223            2223
# mean                   NaN            NaN              NaN             NaN
# std                    NaN            NaN              NaN             NaN
# min                    NaN            NaN              NaN             NaN
# 25%                    NaN            NaN              NaN             NaN
# 50%                    NaN            NaN              NaN             NaN
# 75%                    NaN            NaN              NaN             NaN
# max                    NaN            NaN              NaN             NaN
#
#         Previous Purchases Payment Method Frequency of Purchases
# count          3900.000000           3900                   3900
# unique                 NaN              6                      7
# top                    NaN         PayPal         Every 3 Months
# freq                   NaN            677                    584
# mean             25.351538            NaN                    NaN
# std              14.447125            NaN                    NaN
# min               1.000000            NaN                    NaN
# 25%              13.000000            NaN                    NaN
# 50%              25.000000            NaN                    NaN
# 75%              38.000000            NaN                    NaN
# max              50.000000            NaN                    NaN

# %% [markdown]
# ## 3. Missing Value Analysis and Treatment
#
# First, we'll identify any missing values in our dataset:
# 1. Check for null values in each column
# 2. Handle missing review ratings by using category means
# 3. Verify that all missing values are properly handled
#
# This ensures data completeness and maintains statistical validity.

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating']=df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.mean()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# ## 4. Data Standardization
#
# Standardize column names for consistency and ease of use:
# - Convert to lowercase
# - Replace spaces with underscores
# - Remove special characters
# - Follow Python naming conventions
#
# This makes the data easier to work with and maintains code readability.

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace('(', '')
df.columns = df.columns.str.replace(')', '')

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_usd', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %% [markdown]
# ## 5. Feature Engineering: Customer Segmentation
#
# Create age-based customer segments for better analysis:
# - Teen (18-20)
# - Young Adult (20-30)
# - Adult (30-45)
# - Middle-Aged (45-60)
# - Senior (60-100)
#
# This segmentation enables:
# - Targeted marketing strategies
# - Age-specific analysis
# - Customer behavior patterns by age group

# %%
#Create new column age_group

bins = [18, 20, 30, 45, 60, 100]
groups =['Teen', 'Young Adult','Adult','Middle-Aged','Senior']

df['age_group'] = pd.cut(df['age'], bins=bins, labels=groups, right=False)

# %%
df.head(100)
# Out:
#     customer_id  age gender item_purchased     category  purchase_amount_usd  \
# 0             1   55   Male         Blouse     Clothing                   53
# 1             2   19   Male        Sweater     Clothing                   64
# 2             3   50   Male          Jeans     Clothing                   73
# 3             4   21   Male        Sandals     Footwear                   90
# 4             5   45   Male         Blouse     Clothing                   49
# ..          ...  ...    ...            ...          ...                  ...
# 95           96   37   Male       Sneakers     Footwear                  100
# 96           97   32   Male         Gloves  Accessories                   73
# 97           98   21   Male          Shoes     Footwear                   92
# 98           99   20   Male          Jeans     Clothing                   67
# 99          100   26   Male         Hoodie     Clothing                   40
#
#          location size      color  season  review_rating subscription_status  \
# 0        Kentucky    L       Gray  Winter       3.100000                 Yes
# 1           Maine    L     Maroon  Winter       3.100000                 Yes
# 2   Massachusetts    S     Maroon  Spring       3.100000                 Yes
# 3    Rhode Island    M     Maroon  Spring       3.500000                 Yes
# 4          Oregon    M  Turquoise  Spring       2.700000                 Yes
# ..            ...  ...        ...     ...            ...                 ...
# 95       Missouri    L       Pink    Fall       3.800000                 Yes
# 96       Delaware    S       Gold  Spring       3.769976                 Yes
# 97       Virginia    M       Teal  Winter       4.800000                 Yes
# 98       New York   XL       Teal  Spring       2.600000                 Yes
# 99       Missouri   XL     Indigo  Summer       3.700000                 Yes
#
#     shipping_type discount_applied promo_code_used  previous_purchases  \
# 0         Express              Yes             Yes                  14
# 1         Express              Yes             Yes                   2
# 2   Free Shipping              Yes             Yes                  23
# 3    Next Day Air              Yes             Yes                  49
# 4   Free Shipping              Yes             Yes                  31
# ..            ...              ...             ...                 ...
# 95  Free Shipping              Yes             Yes                  48
# 96        Express              Yes             Yes                  43
# 97   Store Pickup              Yes             Yes                  37
# 98   Next Day Air              Yes             Yes                  20
# 99        Express              Yes             Yes                  33
#
#    payment_method frequency_of_purchases    age_group
# 0           Venmo            Fortnightly  Middle-Aged
# 1            Cash            Fortnightly         Teen
# 2     Credit Card                 Weekly  Middle-Aged
# 3          PayPal                 Weekly  Young Adult
# 4          PayPal               Annually  Middle-Aged
# ..            ...                    ...          ...
# 95         PayPal                Monthly        Adult
# 96          Venmo         Every 3 Months        Adult
# 97           Cash               Annually  Young Adult
# 98  Bank Transfer               Annually  Young Adult
# 99     Debit Card              Quarterly  Young Adult
#
# [100 rows x 19 columns]

# %%
df[['age','age_group']].head(100)
# Out:
#     age    age_group
# 0    55  Middle-Aged
# 1    19         Teen
# 2    50  Middle-Aged
# 3    21  Young Adult
# 4    45  Middle-Aged
# ..  ...          ...
# 95   37        Adult
# 96   32        Adult
# 97   21  Young Adult
# 98   20  Young Adult
# 99   26  Young Adult
#
# [100 rows x 2 columns]

# %%
df['age_group'].unique()
# Out:
# ['Middle-Aged', 'Teen', 'Young Adult', 'Senior', 'Adult']
# Categories (5, object): ['Teen' < 'Young Adult' < 'Adult' < 'Middle-Aged' < 'Senior']

# %% [markdown]
# ## 6. Purchase Frequency Standardization
#
# Convert text-based purchase frequencies to numerical days for analysis:
# - Weekly → 7 days
# - Bi-Weekly/Fortnightly → 14 days
# - Monthly → 30 days
# - Quarterly → 90 days
# - Annually → 365 days
#
# Benefits:
# - Consistent time-based analysis
# - Easier comparison of purchase patterns
# - Better customer behavior insights

# %%
df['frequency_of_purchases'].unique()
# Out:
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months'], dtype=object)

# %%
#create column purchase_frequency_in_days

frequency_mapping={'Fortnightly':14,'Weekly':7,'Monthly':30,'Bi-Weekly':14,'Annually':365,'Quarterly':90,'Every 3 Months':90}

df['purchase_frequency_in_days'] = df['frequency_of_purchases'].map(frequency_mapping)
#

# %%
df['purchase_frequency_in_days'].unique()
# Out:
# array([ 14,   7, 365,  90,  30])

# %%
df.head(100)
# Out:
#     customer_id  age gender item_purchased     category  purchase_amount_usd  \
# 0             1   55   Male         Blouse     Clothing                   53
# 1             2   19   Male        Sweater     Clothing                   64
# 2             3   50   Male          Jeans     Clothing                   73
# 3             4   21   Male        Sandals     Footwear                   90
# 4             5   45   Male         Blouse     Clothing                   49
# ..          ...  ...    ...            ...          ...                  ...
# 95           96   37   Male       Sneakers     Footwear                  100
# 96           97   32   Male         Gloves  Accessories                   73
# 97           98   21   Male          Shoes     Footwear                   92
# 98           99   20   Male          Jeans     Clothing                   67
# 99          100   26   Male         Hoodie     Clothing                   40
#
#          location size      color  season  review_rating subscription_status  \
# 0        Kentucky    L       Gray  Winter       3.100000                 Yes
# 1           Maine    L     Maroon  Winter       3.100000                 Yes
# 2   Massachusetts    S     Maroon  Spring       3.100000                 Yes
# 3    Rhode Island    M     Maroon  Spring       3.500000                 Yes
# 4          Oregon    M  Turquoise  Spring       2.700000                 Yes
# ..            ...  ...        ...     ...            ...                 ...
# 95       Missouri    L       Pink    Fall       3.800000                 Yes
# 96       Delaware    S       Gold  Spring       3.769976                 Yes
# 97       Virginia    M       Teal  Winter       4.800000                 Yes
# 98       New York   XL       Teal  Spring       2.600000                 Yes
# 99       Missouri   XL     Indigo  Summer       3.700000                 Yes
#
#     shipping_type discount_applied promo_code_used  previous_purchases  \
# 0         Express              Yes             Yes                  14
# 1         Express              Yes             Yes                   2
# 2   Free Shipping              Yes             Yes                  23
# 3    Next Day Air              Yes             Yes                  49
# 4   Free Shipping              Yes             Yes                  31
# ..            ...              ...             ...                 ...
# 95  Free Shipping              Yes             Yes                  48
# 96        Express              Yes             Yes                  43
# 97   Store Pickup              Yes             Yes                  37
# 98   Next Day Air              Yes             Yes                  20
# 99        Express              Yes             Yes                  33
#
#    payment_method frequency_of_purchases    age_group  \
# 0           Venmo            Fortnightly  Middle-Aged
# 1            Cash            Fortnightly         Teen
# 2     Credit Card                 Weekly  Middle-Aged
# 3          PayPal                 Weekly  Young Adult
# 4          PayPal               Annually  Middle-Aged
# ..            ...                    ...          ...
# 95         PayPal                Monthly        Adult
# 96          Venmo         Every 3 Months        Adult
# 97           Cash               Annually  Young Adult
# 98  Bank Transfer               Annually  Young Adult
# 99     Debit Card              Quarterly  Young Adult
#
#     purchase_frequency_in_days
# 0                           14
# 1                           14
# 2                            7
# 3                            7
# 4                          365
# ..                         ...
# 95                          30
# 96                          90
# 97                         365
# 98                         365
# 99                          90
#
# [100 rows x 20 columns]

# %%
df[['frequency_of_purchases','purchase_frequency_in_days']].head(50)
# Out:
#    frequency_of_purchases  purchase_frequency_in_days
# 0             Fortnightly                          14
# 1             Fortnightly                          14
# 2                  Weekly                           7
# 3                  Weekly                           7
# 4                Annually                         365
# 5                  Weekly                           7
# 6               Quarterly                          90
# 7                  Weekly                           7
# 8                Annually                         365
# 9               Quarterly                          90
# 10              Bi-Weekly                          14
# 11            Fortnightly                          14
# 12            Fortnightly                          14
# 13                 Weekly                           7
# 14                 Weekly                           7
# 15                Monthly                          30
# 16              Bi-Weekly                          14
# 17              Quarterly                          90
# 18                 Weekly                           7
# 19              Bi-Weekly                          14
# 20         Every 3 Months                          90
# 21              Quarterly                          90
# 22               Annually                         365
# 23                 Weekly                           7
# 24                 Weekly                           7
# 25               Annually                         365
# 26               Annually                         365
# 27         Every 3 Months                          90
# 28         Every 3 Months                          90
# 29                 Weekly                           7
# 30                Monthly                          30
# 31                Monthly                          30
# 32               Annually                         365
# 33              Quarterly                          90
# 34              Quarterly                          90
# 35              Bi-Weekly                          14
# 36            Fortnightly                          14
# 37                 Weekly                           7
# 38         Every 3 Months                          90
# 39                Monthly                          30
# 40              Quarterly                          90
# 41               Annually                         365
# 42               Annually                         365
# 43            Fortnightly                          14
# 44                 Weekly                           7
# 45               Annually                         365
# 46              Quarterly                          90
# 47                 Weekly                           7
# 48                Monthly                          30
# 49              Bi-Weekly                          14

# %%
df[['discount_applied','promo_code_used']].head(100)
# Out:
#    discount_applied promo_code_used
# 0               Yes             Yes
# 1               Yes             Yes
# 2               Yes             Yes
# 3               Yes             Yes
# 4               Yes             Yes
# ..              ...             ...
# 95              Yes             Yes
# 96              Yes             Yes
# 97              Yes             Yes
# 98              Yes             Yes
# 99              Yes             Yes
#
# [100 rows x 2 columns]

# %%
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# np.True_

# %%
df=df.drop('promo_code_used',axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_usd', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_in_days'],
#       dtype='object')

# %%
# !pip install --upgrade pip
# !pip install sqlalchemy pandas
# !pip install "cloud-sql-python-connector[pg8000]" pg8000
# Out:
# Requirement already satisfied: pip in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (25.1.1)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# C:\Users\b\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
# Requirement already satisfied: sqlalchemy in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (2.0.44)
# Requirement already satisfied: pandas in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: greenlet>=1 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (4.14.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\b\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\b\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pg8000 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (1.31.5)
# Requirement already satisfied: cloud-sql-python-connector[pg8000] in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (1.18.5)
# Requirement already satisfied: aiofiles in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from cloud-sql-python-connector[pg8000]) (25.1.0)
# Requirement already satisfied: aiohttp in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from cloud-sql-python-connector[pg8000]) (3.13.2)
# Requirement already satisfied: cryptography>=42.0.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from cloud-sql-python-connector[pg8000]) (46.0.3)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from cloud-sql-python-connector[pg8000]) (2.8.0)
# Requirement already satisfied: Requests in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from cloud-sql-python-connector[pg8000]) (2.32.4)
# Requirement already satisfied: google-auth>=2.28.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from cloud-sql-python-connector[pg8000]) (2.40.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\b\appdata\roaming\python\python313\site-packages (from pg8000) (2.9.0.post0)
# Requirement already satisfied: scramp>=1.4.5 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from pg8000) (1.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=42.0.0->cloud-sql-python-connector[pg8000]) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=42.0.0->cloud-sql-python-connector[pg8000]) (2.23)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=2.28.0->cloud-sql-python-connector[pg8000]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=2.28.0->cloud-sql-python-connector[pg8000]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=2.28.0->cloud-sql-python-connector[pg8000]) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.28.0->cloud-sql-python-connector[pg8000]) (0.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\b\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pg8000) (1.17.0)
# Requirement already satisfied: asn1crypto>=1.5.1 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from scramp>=1.4.5->pg8000) (1.5.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->cloud-sql-python-connector[pg8000]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->cloud-sql-python-connector[pg8000]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->cloud-sql-python-connector[pg8000]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->cloud-sql-python-connector[pg8000]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->cloud-sql-python-connector[pg8000]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->cloud-sql-python-connector[pg8000]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->cloud-sql-python-connector[pg8000]) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->cloud-sql-python-connector[pg8000]) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from Requests->cloud-sql-python-connector[pg8000]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from Requests->cloud-sql-python-connector[pg8000]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b\appdata\local\programs\python\python313\lib\site-packages (from Requests->cloud-sql-python-connector[pg8000]) (2025.7.14)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 7. Database Integration Setup
#
# Prepare for data persistence in PostgreSQL:
# 1. Install required dependencies
# 2. Set up database connection
# 3. Configure SQLAlchemy engine
# 4. Load processed data into database
#
# This enables:
# - Permanent storage of processed data
# - SQL-based analysis capabilities
# - Data sharing across applications
# - Integration with other systems

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# Step 1: Connect to PostgreSQL
# Replace placeholders with your actual details
username = "postgres"      # default user
password = "Myuser@1234" # the password you set during installation (may contain special chars like @)
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "customerdata"    # the database you created in pgAdmin

# URL-encode username/password to avoid breaking the connection URL when they contain special characters
password_enc = quote_plus(password)

engine = create_engine(f"postgresql+psycopg2://{username}:{password_enc}@{host}:{port}/{database}")

# Step 2: Load DataFrame into PostgreSQL
table_name = "customer_purchases"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'customer_purchases' in database 'customerdata'.
